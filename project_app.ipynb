# %% [markdown]
# # Exploratory Data Analysis

# %%
from pyspark import SparkContext, SparkConf
from pyspark.sql import SparkSession
import pyspark.sql.functions as f

# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set(style='whitegrid')

# %% [markdown]
# ### Spark Session

# %%
spark = SparkSession \
        .builder \
        .appName("Push to MongoDB") \
        .master("spark://master:7077") \
        .config("spark.mongodb.input.uri", "mongodb://project1261:pass1261@mongo/test.coll?authSource=admin") \
        .config("spark.mongodb.output.uri", "mongodb://project1261:pass1261@mongo/test.coll?authSource=admin") \
        .config('spark.jars.packages', 'org.mongodb.spark:mongo-spark-connector_2.11:2.4.0')\
        .getOrCreate()

spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://45f4955e27a0:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v2.4.4</code></dd>
#               <dt>Master</dt>
#                 <dd><code>spark://master:7077</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Push to MongoDB</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ### Reading the dataset

# %% [markdown]
# The dataset is about registered Montreal traffic accidents from 2012 to 2018.

# %%
df = pd.read_csv('../data/accidents_2012_2018.csv')

# %% [markdown]
# ### Summarizing your data for inspection

# %%
# Cheking the structure of the dataframe
df
# Out:
#                 NO_SEQ_COLL JR_SEMN_ACCDN    DT_ACCDN  CD_MUNCP  \
# 0           SPVM _ 2012 _ 1            ME  2012/02/01   66102.0
# 1           SPVM _ 2012 _ 2            SA  2012/06/02   66023.0
# 2           SPVM _ 2012 _ 3            JE  2012/06/28   66023.0
# 3           SPVM _ 2012 _ 4            ME  2012/07/11   66023.0
# 4           SPVM _ 2012 _ 5            LU  2012/01/02   66023.0
# ...                     ...           ...         ...       ...
# 171266  SPVM _ 2018 _ 21381            VE  2018/12/28   66102.0
# 171267  SPVM _ 2018 _ 21382            DI  2018/12/30   66102.0
# 171268  SPVM _ 2018 _ 21383            LU  2018/12/31   66102.0
# 171269  SPVM _ 2018 _ 21384            LU  2018/12/31   66102.0
# 171270  SPVM _ 2018 _ 21385            DI  2018/05/20   66102.0
#
#         NO_CIVIQ_ACCDN SFX_NO_CIVQ_ACCDN  BORNE_KM_ACCDN      RUE_ACCDN  \
# 0               3501.0               NaN             NaN     ST CHARLES
# 1                  NaN               NaN             NaN            NaN
# 2                  NaN               NaN             NaN     COTE VERTU
# 3                  NaN               NaN             NaN     ST MATHIEU
# 4               4849.0               NaN             NaN        ST JEAN
# ...                ...               ...             ...            ...
# 171266             NaN               NaN             NaN            NaN
# 171267          3701.0               NaN             NaN  ST CHARLES BD
# 171268          2989.0               NaN             NaN     ST CHARLES
# 171269          3535.0               NaN             NaN     ST CHARLES
# 171270          3035.0               NaN             NaN  BD ST CHARLES
#
#         TP_REPRR_ACCDN         ACCDN_PRES_DE  ...  NB_VICTIMES_VELO  \
# 0                  2.0                  STAT  ...                 0
# 1                  NaN  COTE VERTU ET AUT 40  ...                 0
# 2                  1.0               DECARIE  ...                 0
# 3                  1.0         RENE LEVESQUE  ...                 0
# 4                  NaN                   NaN  ...                 0
# ...                ...                   ...  ...               ...
# 171266             NaN                   NaN  ...                 0
# 171267             NaN                   NaN  ...                 0
# 171268             NaN                 HYMUS  ...                 0
# 171269             2.0                  STAT  ...                 0
# 171270             NaN     STATION SERV ESSO  ...                 0
#
#         VITESSE_AUTOR         LOC_X         LOC_Y  LOC_COTE_Q  LOC_COTE_P  \
# 0                 NaN  276517.37950  5.035127e+06           A           3
# 1                 NaN  287913.26000  5.038666e+06           A           3
# 2                50.0  290518.82501  5.041617e+06           A           1
# 3                50.0  298822.88600  5.039146e+06           A           3
# 4                 NaN  277433.35738  5.038881e+06           A           1
# ...               ...           ...           ...         ...         ...
# 171266            NaN  273169.33255  5.032564e+06           C           4
# 171267           10.0  276236.96441  5.035562e+06           A           1
# 171268            NaN  277038.85838  5.034371e+06           A           1
# 171269            NaN  276406.91433  5.035291e+06           A           1
# 171270            NaN  277036.85838  5.034367e+06           A           1
#
#         LOC_DETACHEE  LOC_IMPRECISION   LOC_LONG    LOC_LAT
# 0                  O                N -73.861616  45.455505
# 1                  N                O -73.716033  45.487715
# 2                  N                N -73.682786  45.514324
# 3                  N                N -73.576472  45.492212
# 4                  O                N -73.850114  45.489319
# ...              ...              ...        ...        ...
# 171266             N                N -73.904258  45.432297
# 171267             O                N -73.865226  45.459403
# 171268             O                N -73.854906  45.448722
# 171269             O                N -73.863038  45.456970
# 171270             N                N -73.854931  45.448686
#
# [171271 rows x 68 columns]

# %%
# Getting more info about the dataset
print('### Montreal Accidents summary ###')
print('\n')
print(df.columns)
print('\n')
print(df.head())
print('\n')
print(df.describe())
print('\n')
print("Shape of dataframe")
df.shape
# Out:
# ### Montreal Accidents summary ###
#
#
# Index(['NO_SEQ_COLL', 'JR_SEMN_ACCDN', 'DT_ACCDN', 'CD_MUNCP',
#        'NO_CIVIQ_ACCDN', 'SFX_NO_CIVQ_ACCDN', 'BORNE_KM_ACCDN', 'RUE_ACCDN',
#        'TP_REPRR_ACCDN', 'ACCDN_PRES_DE', 'NB_METRE_DIST_ACCD',
#        'CD_GENRE_ACCDN', 'CD_SIT_PRTCE_ACCDN', 'CD_ETAT_SURFC', 'CD_ECLRM',
#        'CD_ENVRN_ACCDN', 'NO_ROUTE', 'CD_CATEG_ROUTE', 'CD_ETAT_CHASS',
#        'CD_ASPCT_ROUTE', 'CD_LOCLN_ACCDN', 'CD_POSI_ACCDN', 'CD_CONFG_ROUTE',
#        'CD_ZON_TRAVX_ROUTR', 'CD_PNT_CDRNL_ROUTE', 'CD_PNT_CDRNL_REPRR',
#        'CD_COND_METEO', 'NB_VEH_IMPLIQUES_ACCDN', 'NB_MORTS',
#        'NB_BLESSES_GRAVES', 'NB_BLESS_LEGERS', 'HR_ACCDN', 'AN',
#        'NB_VICTIMES_TOTAL', 'GRAVITE', 'REG_ADM', 'MRC',
#        'nb_automobile_camion_leger', 'nb_camionLourd_tractRoutier',
#        'nb_outil_equipement', 'nb_tous_autobus_minibus', 'nb_bicyclette',
#        'nb_cyclomoteur', 'nb_motocyclette', 'nb_taxi', 'nb_urgence',
#        'nb_motoneige', 'nb_VHR', 'nb_autres_types', 'nb_veh_non_precise',
#        'NB_DECES_PIETON', 'NB_BLESSES_PIETON', 'NB_VICTIMES_PIETON',
#        'NB_DECES_MOTO', 'NB_BLESSES_MOTO', 'NB_VICTIMES_MOTO', 'NB_DECES_VELO',
#        'NB_BLESSES_VELO', 'NB_VICTIMES_VELO', 'VITESSE_AUTOR', 'LOC_X',
#        'LOC_Y', 'LOC_COTE_Q', 'LOC_COTE_P', 'LOC_DETACHEE', 'LOC_IMPRECISION',
#        'LOC_LONG', 'LOC_LAT'],
#       dtype='object')
#
#
#        NO_SEQ_COLL JR_SEMN_ACCDN    DT_ACCDN  CD_MUNCP  NO_CIVIQ_ACCDN  \
# 0  SPVM _ 2012 _ 1            ME  2012/02/01   66102.0          3501.0
# 1  SPVM _ 2012 _ 2            SA  2012/06/02   66023.0             NaN
# 2  SPVM _ 2012 _ 3            JE  2012/06/28   66023.0             NaN
# 3  SPVM _ 2012 _ 4            ME  2012/07/11   66023.0             NaN
# 4  SPVM _ 2012 _ 5            LU  2012/01/02   66023.0          4849.0
#
#   SFX_NO_CIVQ_ACCDN  BORNE_KM_ACCDN   RUE_ACCDN  TP_REPRR_ACCDN  \
# 0               NaN             NaN  ST CHARLES             2.0
# 1               NaN             NaN         NaN             NaN
# 2               NaN             NaN  COTE VERTU             1.0
# 3               NaN             NaN  ST MATHIEU             1.0
# 4               NaN             NaN     ST JEAN             NaN
#
#           ACCDN_PRES_DE  ...  NB_VICTIMES_VELO  VITESSE_AUTOR         LOC_X  \
# 0                  STAT  ...                 0            NaN  276517.37950
# 1  COTE VERTU ET AUT 40  ...                 0            NaN  287913.26000
# 2               DECARIE  ...                 0           50.0  290518.82501
# 3         RENE LEVESQUE  ...                 0           50.0  298822.88600
# 4                   NaN  ...                 0            NaN  277433.35738
#
#           LOC_Y  LOC_COTE_Q  LOC_COTE_P  LOC_DETACHEE  LOC_IMPRECISION  \
# 0  5.035127e+06           A           3             O                N
# 1  5.038666e+06           A           3             N                O
# 2  5.041617e+06           A           1             N                N
# 3  5.039146e+06           A           3             N                N
# 4  5.038881e+06           A           1             O                N
#
#     LOC_LONG    LOC_LAT
# 0 -73.861616  45.455505
# 1 -73.716033  45.487715
# 2 -73.682786  45.514324
# 3 -73.576472  45.492212
# 4 -73.850114  45.489319
#
# [5 rows x 68 columns]
#
#
#             CD_MUNCP  NO_CIVIQ_ACCDN  BORNE_KM_ACCDN  TP_REPRR_ACCDN  \
# count  171267.000000     73806.00000       37.000000   105326.000000
# mean    66023.559904      4746.73788     1092.918919        1.125078
# std       523.124277      3798.01277     2031.971539        0.331182
# min      1023.000000         0.00000        1.000000        0.000000
# 25%     66023.000000      1475.00000       62.300000        1.000000
# 50%     66023.000000      4405.00000       87.300000        1.000000
# 75%     66023.000000      7100.00000      670.100000        1.000000
# max     94210.000000     97850.00000     8410.000000        2.000000
#
#        NB_METRE_DIST_ACCD  CD_GENRE_ACCDN  CD_SIT_PRTCE_ACCDN  CD_ETAT_SURFC  \
# count        43096.000000   162226.000000         3872.000000  159998.000000
# mean           103.771858       33.592180            4.867769      12.389117
# std           1982.397785        9.329315            3.555745       5.620648
# min              0.000000       31.000000            1.000000      11.000000
# 25%             10.000000       31.000000            1.000000      11.000000
# 50%             20.000000       31.000000            3.000000      11.000000
# 75%             50.000000       31.000000            9.000000      12.000000
# max          66142.000000       99.000000            9.000000      99.000000
#
#             CD_ECLRM  CD_ENVRN_ACCDN  ...  NB_VICTIMES_MOTO  NB_DECES_VELO  \
# count  159868.000000   165314.000000  ...     171271.000000  171271.000000
# mean        1.615714        2.651615  ...          0.007579       0.000146
# std         0.903946        0.916632  ...          0.091124       0.012081
# min         1.000000        1.000000  ...          0.000000       0.000000
# 25%         1.000000        2.000000  ...          0.000000       0.000000
# 50%         1.000000        3.000000  ...          0.000000       0.000000
# 75%         3.000000        3.000000  ...          0.000000       0.000000
# max         4.000000        9.000000  ...          3.000000       1.000000
#
#        NB_BLESSES_VELO  NB_VICTIMES_VELO  VITESSE_AUTOR          LOC_X  \
# count    171271.000000     171271.000000  103281.000000  171260.000000
# mean          0.028843          0.028989      46.283440  295231.060266
# std           0.168062          0.168471       7.582045    6077.139916
# min           0.000000          0.000000      10.000000  267986.992400
# 25%           0.000000          0.000000      40.000000  293395.573520
# 50%           0.000000          0.000000      50.000000  296464.800000
# 75%           0.000000          0.000000      50.000000  299204.100000
# max           2.000000          2.000000     100.000000  306367.983980
#
#               LOC_Y     LOC_COTE_P       LOC_LONG        LOC_LAT
# count  1.712600e+05  171271.000000  171260.000000  171260.000000
# mean   5.042938e+06       1.203444     -73.622466      45.526267
# std    5.935289e+03       0.583383       0.077707       0.053460
# min    5.029289e+06       1.000000     -73.970506      45.402674
# 25%    5.038839e+06       1.000000     -73.645879      45.489314
# 50%    5.042675e+06       1.000000     -73.606730      45.523963
# 75%    5.046864e+06       1.000000     -73.571686      45.561651
# max    5.062512e+06       4.000000     -73.479864      45.702491
#
# [8 rows x 53 columns]
#
#
# Shape of dataframe
# (171271, 68)

# %%
df.groupby(by='GRAVITE')['NB_VICTIMES_TOTAL'].count()
# Out:
# GRAVITE
# Dommages matériels inférieurs au seuil de rapportage    71665
# Dommages matériels seulement                            63662
# Grave                                                    1411
# Léger                                                   34354
# Mortel                                                    179
# Name: NB_VICTIMES_TOTAL, dtype: int64

# %%
df.groupby(by='JR_SEMN_ACCDN')['NB_VICTIMES_TOTAL'].count()
# Out:
# JR_SEMN_ACCDN
# DI    18637
# JE    27490
# LU    23924
# MA    25595
# ME    25844
# SA    22103
# VE    27678
# Name: NB_VICTIMES_TOTAL, dtype: int64

# %%
fig = plt.figure(figsize=(50, 50))
fig.subplots_adjust(top=0.85, wspace=0.3)

ax1 = fig.add_subplot(3,3,1)
bar1 = sns.countplot(x = "GRAVITE", order=["Mortel","Grave", "Léger", "Dommages matériels \
seulement", "Dommages matériels inférieurs au seuil de rapportage"], palette="Set2", data = df)

ax2 = fig.add_subplot(3,3,2)
bar2 = sns.countplot(x = "JR_SEMN_ACCDN", order=["DI","LU","MA", "ME", "JE", "VE", "SA"], palette="Set2", data = df)

# %%
# Checking for missing values by columns
print(df.isnull().sum())
# Out:
# NO_SEQ_COLL            0
# JR_SEMN_ACCDN          0
# DT_ACCDN               0
# CD_MUNCP               4
# NO_CIVIQ_ACCDN     97465
#                    ...
# LOC_COTE_P             0
# LOC_DETACHEE           8
# LOC_IMPRECISION        0
# LOC_LONG              11
# LOC_LAT               11
# Length: 68, dtype: int64

# %%
## Assigning value zero for the NaN cases
df.fillna(value=0,inplace=True)
print(df.isnull().sum())
# Out:
# NO_SEQ_COLL        0
# JR_SEMN_ACCDN      0
# DT_ACCDN           0
# CD_MUNCP           0
# NO_CIVIQ_ACCDN     0
#                   ..
# LOC_COTE_P         0
# LOC_DETACHEE       0
# LOC_IMPRECISION    0
# LOC_LONG           0
# LOC_LAT            0
# Length: 68, dtype: int64

# %%
# heatmap
corrmat = df.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True)
plt.show()
plt.savefig('../figures/Accidents_Attributes_Correlation_Heatmap.png')

# %%
df.to_csv('../data/accidents_2012_2018_processed.csv', index=False)
